# %% [markdown]
# <a href="https://colab.research.google.com/github/Sainiakshay798/QR_CODE_GENERATOR/blob/main/QR_CODE_GENERATOR_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import qrcode
import matplotlib.pyplot as plt




name = 'Akshay saini'
Email = 'akshaysaini2005@gmail.com'
contact = 9079817260
Address = 'VPO,KESRISINGHPUR, SRI GANGANAGAR,RAJASTHAN, INDIA'

data = f'name :{name} \n Email :{Email}\n contact{contact}\n Address{Address } '
filename = "my.png"
image = qrcode.make(data)
image.save(filename)
plt.imshow(image,cmap='gray')
